# %%
import scipy.spatial
import numpy as np

f0 = open('xyz' , 'r')
f1 = open('xyzc', 'r', encoding="utf-8")
f2 = open('xyz_v2' , 'r')

# xyz_v2 include more type of pipe
xyz_v2 = []
# xyz include only one type of type
xyz  = []
xyzc = []

class dataset:
    def __init__(self):
        self.pipe_coordinate=list()
        self.connector_coordinate=list()
    def import_pipe(self,pipe):
        self.src_pipe=pipe
    def import_pipe_v2(self,pipe_v2):
        self.src_pipe_v2=pipe_v2
    def import_connector(self,connector):
        self.src_connector=connector
    def pre_processing_pipe(self):
        for i in self.src_pipe:
            tmplist=list()
            for j in i:
                # tmplist.append(j[:3])
                self.pipe_coordinate.append(j[:3])
    def pre_processing_connector(self):
        for i in self.src_connector:
            self.connector_coordinate.append(i[:3])


processor=dataset()

#讀取資料
for i in f0.readlines():
    temp0 = []
    temp1 = []
    temp2 = i.split(', ')

    for j in range(len(temp2)):
        if j <= 2:
            temp0.append(float(temp2[j]))
        elif j == 3:
            temp2[j] = temp2[j].split('\n')
            temp0.append(float(temp2[j][0]))
        elif 3 < j <= 6:
            temp1.append(float(temp2[j]))
        elif j == 7:
            temp2[j] = temp2[j].split('\n')
            temp1.append(float(temp2[j][0]))
    xyz.append([temp0, temp1])

for i in f2.readlines():
    temp0 = []
    temp1 = []
    temp2 = i.split(', ')

    for j in range(len(temp2)):
        if j <= 2:
            temp0.append(float(temp2[j]))
        elif j == 3:
            temp2[j] = temp2[j].split('\n')
            temp0.append(float(temp2[j][0]))
        elif 3 < j <= 6:
            temp1.append(float(temp2[j]))
        elif j == 7:
            temp2[j] = temp2[j].split('\n')
            temp1.append(float(temp2[j][0]))
    xyz_v2.append([temp0, temp1])

for i in f1.readlines():
    temp0 = []
    temp1 = i.split(', ')
    for j in range(0, 5):
        if j <= 2:
            temp0.append(float(temp1[j]))
        elif j == 3:
            temp0.append(temp1[j])
        elif j == 4:
            temp1[j] = temp1[j].split('\n')
            temp0.append(int(temp1[j][0]))
    xyzc.append(temp0)

tmp_src_pipe=list()
tmp_src_pipe_v2=list()

for i in xyz:
    tmp_src_pipe.append(i[0])
    tmp_src_pipe.append(i[1])

for i in xyz_v2:
    tmp_src_pipe_v2.append(i[0])
    tmp_src_pipe_v2.append(i[1])


processor.import_pipe(xyz)
processor.pre_processing_pipe()
processor.import_pipe(tmp_src_pipe)
processor.import_connector(xyzc)
processor.pre_processing_connector()

processor.import_pipe(tmp_src_pipe_v2)

# %%
distance=scipy.spatial.distance_matrix(
                    processor.pipe_coordinate,
                    processor.connector_coordinate)

# %%
endpoint_pipe=list()
endpoint_connector=list()
idx=0
for i in distance:
    # suppose all distance > pow(7000,0.5)
    flag=1
    for j in i:
        # if find any distance between pipe and connector is less than pow(7000,0.5
        # It must not a start pipe
        if(j<pow(7000,0.5)):
            flag=0
            break
    if flag:
        endpoint_pipe.append(idx)
        # print(idx)
    idx+=1

# find start and end point of connector
# If distance between a pipe and all connector > pow(7000,0.5)
# then it should be a start connector
# idx=0

for i in range(0,len(distance[0])):
    num_of_next=0
 0], [744, 0], [746, 0], [749, 0], [750, 0], [752, 0], [770, 0], [771, 0], [772, 0], [773, 0], [810, 0], [811, 1], [822, 0], [831, 0], [859, 0], [876, 0], [877, 0], [878, 0], [879, 0], [880, 0], [881, 0], [882, 0], [884, 0], [885, 0], [886, 0], [887, 0], [888, 0], [889, 0], [890, 0], [891, 0], [892, 0], [893, 0], [894, 0], [895, 0], [896, 0], [897, 0], [899, 0], [900, 0], [901, 0], [902, 0], [903, 0], [904, 0], [905, 0], [906, 0], [907, 0], [908, 0], [909, 0], [910, 0], [911, 0], [912, 0], [914, 0], [915, 0], [916, 0], [917, 0], [918, 0], [919, 0], [920, 0], [921, 0], [922, 0], [923, 0], [934, 0], [935, 0], [936, 0], [937, 0], [938, 0], [939, 0], [941, 0], [943, 0], [944, 0], [945, 0], [946, 0], [947, 0], [948, 0], [949, 0], [950, 0], [951, 0], [952, 0], [954, 0], [956, 0], [978, 0], [979, 0], [980, 0], [981, 0], [982, 0], [983, 0], [1008, 0], [1009, 0], [1010, 0], [1011, 0], [1012, 0], [1013, 0], [1014, 0], [1015, 0], [1016, 0], [1017, 0], [1024, 0], [1030, 1], [1031, 1], [1034, 0], [1035, 0], [1036, 0], [1037, 0], [1038, 1], [1039, 0], [1040, 0], [1043, 0], [1044, 0], [1045, 0], [1046, 0], [1051, 0], [1061, 0], [1062, 0], [1071, 0], [1073, 0], [1074, 0], [1076, 0], [1077, 0], [1078, 0], [1079, 0], [1080, 0], [1081, 0], [1082, 0], [1083, 0], [1084, 0], [1085, 0], [1086, 0], [1087, 0], [1088, 0], [1089, 0], [1090, 0], [1091, 0], [1092, 0], [1093, 0], [1094, 0], [1095, 0], [1148, 1], [1150, 0], [1151, 0], [1152, 0], [1153, 0], [1158, 1], [1159, 1], [1160, 0], [1161, 0], [1170, 0], [1171, 0], [1172, 0], [1173, 0], [1174, 0], [1176, 0], [1177, 0], [1178, 0], [1179, 0], [1180, 0], [1182, 0], [1183, 0], [1185, 0], [1199, 0], [1200, 1], [1202, 0], [1203, 1], [1205, 1], [1207, 0], [1211, 0], [1216, 0], [1217, 1], [1230, 0], [1258, 0], [1259, 0], [1263, 0], [1264, 0], [1265, 0], [1266, 0], [1267, 0], [1272, 0], [1273, 0]]

# %%
connector_next=list()

# all pipe index: 0~2284
visited_pipe=list(range(0,len(processor.pipe_coordinate)))
# print(len(visited_pipe))

# find connector next pipe
for i in range(0,len(distance[0])):

    # case 2: find next for next
    # number of connector next pipe
    num_of_next=0

    if(processor.src_pipe[i][3]=="M_頂蓋 - 螺紋 - MI - 150 級"):
        num_of_next=1
    elif(processor.src_pipe[i][3]=="M_T 接頭異徑 - 螺紋 - MI - 150 級"):
        num_of_next=3
    else:
        num_of_next=2

    # get distance from remaining pipe
    tmp=list()
    for j in range(0,len(visited_pipe)):
        tmp.append(distance[visited_pipe[j]][i])
    tmpidx=list()
    for j in range(0,len(visited_pipe)):   
        tmpidx.append(visited_pipe[j])
    
    # find sorted num according to origin tmp list index
    sort_tmp=sorted(tmp)
    visited_sort_list=list()
    sort_idx=list()
    for j in range(0,len(tmp)): visited_sort_list.append(0)
    for j in range(0,len(tmp)):
        for k in range(0,len(tmp)):
            if(visited_sort_list[k]!=1 and sort_tmp[j]==tmp[k]):
                visited_sort_list[k]=1
                sort_idx.append(tmpidx[k])
                break
    
    # case 1: already endpoint
    for j in endpoint_connector:
        if i==j[0]:
            # print("yes")
            num_of_next=j[1]
            break

    start_idx=0
    list_len=len(sort_idx)
    store_to_connector_next=list()

    if(num_of_next==1):
        store_to_connector_next.append(-1)
        connector_next.append(store_to_connector_next)
        continue

    while(num_of_next and start_idx<list_len):
        # find same if idx/2==idx'/2
        # since we have [0,1], [2,3] as same pipe
        same_pipe=0
        for j in range(0,len(store_to_connector_next)):
            if(int(sort_idx[start_idx]/2)==int(store_to_connector_next[j]/2)):
                same_pipe=1
        if(same_pipe):
            start_idx+=1
            continue
        store_to_connector_next.append(sort_idx[start_idx])
        visited_pipe.remove(sort_idx[start_idx])
        num_of_next-=1
        start_idx+=1
        # print("remove:",sort_idx[start_idx])

    connector_next.append(store_to_connector_next)
    # all conncetor next pipe index
    # print(len(connector_next))

# %%
# find pipe next connetor
pipe_next=list()
record_id=list()
visited_connector=list(range(0,len(distance[0])))

for i in range(0,len(distance)):
    
    # -2 start and end in same pipe
    # if(processor.src_pipe[i][3] in record_id):
    #     pipe_next.append(-2)
    #     continue

    # record_id.append(processor.src_pipe[i][3])

    # already endpoint
    # if i in endpoint_pipe:
    #     tmp = list()
    #     tmp.append(-1)
    #     pipe_next.append(tmp)
    #     continue

    
    tmp=list()
    # for j in range(0,len(visited_connector)):
    #     tmp.append(distance[i][visited_connector[j]])
    # tmpidx=list()
    for j in range(0,len(distance[i])):   
        tmp.append(distance[i][j])
    
    # # find sorted num according to origin tmp list index
    # sort_tmp=sorted(tmp)
    # visited_sort_list=list()
    # sort_idx=list()
    # for i in range(0,len(tmp)): visited_sort_list.append(0)
    # for i in range(0,len(tmp)):
    #     for j in range(0,len(tmp)):
    #         if(visited_sort_list[j]!=1 and sort_tmp[i]==tmp[j]):
    #             visited_sort_list[j]=1
    #             sort_idx.append(tmpidx[j])
    #             break

    
    minnum=min(tmp)
    minidx=tmp.index(minnum)
    # tmp.append(sort_idx[0])
    pipe_next.append(minidx)
    
print(len(connector_next),len(pipe_next))
print(pipe_next)
print(connector_next)
# Out:
# 1276 2284
# [14, 15, 1245, 14, 1052, 16, 16, 687, 18, 19, 17, 18, 19, 774, 21, 22, 20, 21, 22, 23, 24, 25, 23, 24, 25, 514, 27, 408, 26, 27, 29, 30, 28, 29, 30, 31, 32, 33, 31, 32, 34, 35, 33, 34, 36, 1234, 35, 36, 38, 39, 37, 38, 39, 40, 41, 42, 40, 41, 43, 44, 42, 43, 45, 46, 44, 45, 1121, 1117, 48, 49, 47, 48, 49, 50, 51, 52, 50, 51, 53, 54, 52, 53, 55, 55, 54, 55, 67, 820, 66, 64, 65, 443, 64, 65, 68, 69, 66, 69, 67, 68, 1240, 67, 71, 72, 70, 71, 1241, 70, 356, 78, 79, 439
], [391, 856], [], [], [], [], [], [], [], [393, 394], [399, 400], [395, 404], [396, 406], [402, 407], [403, 405], [392, 410], [408, 411], [], [1848, 1860], [], [], [], [], [], [], [], [], [], [], [1894, 1898], [], [], [], [416, 420], [412, 418], [414, 419], [415, 417], [421, 424], [422, 425], [423, 428], [426, 429], [427, 432], [430, 433], [], [], [], [], [], [], [], [434, 1925], [-1], [1353, 247], [], [], [1643, 1656], [], [], [], [], [], [], [], [], [], [], [449, 450], [458, 464], [456, 459], [462, 452], [463, 2046], [455, 468], [469, 2054], [453, 472], [470, 473], [476, 454], [477, 490], [482, 474], [481, 483], [488, 484], [487, 489], [205, 494], [492, 495], [], [], [500, 258], [], [504, 2113], [311, 321], [-1], [-1], [514, 520], [], [518, 2140], [522, 526], [523, 177], [524, 527], [528, 510], [], [], [532, 530], [], [], [], [285, 539], [541, 543], [540, 181], [511, 529], [], [], [], [-1], [448, 551], [-1], [553, 446], [554, 544], [], [], [], [560, 604], [], [], [566, 626], [567, 564], [451, 570], [571, 568], [], [], [-1], [580, 583], [588, 591], [586, 589], [], [], [-1], [], [600, 599], [577, 601], [602, 171], [595, 603], [557, 545], [163, 605], [607, 610], [608, 611], [609, 614], [612, 615], [616, 628], [617, 620], [618, 621], [623, 625], [627, 447], [629, 622], [631, 632], [633, 634], [637, 638], [639, 640], [], [], [], [], [], [], [], [], [], [1864, 1867], [], [], [], [], [], [], [1808, 1783], [], [], [], [1811, 1782], [], [], [], [], [], [], [1817, 1819], [270, 644], [642, 645], [643, 269], [273, 646], [398, 650], [648, 651], [397, 649], [401, 652], [655, 656], [657, 658], [659, 660], [661, 668], [663, 664], [666, 669], [], [], [], [665, 676], [], [667, 678], [], [680, 682], [683, 684], [685, 686], [687, 698], [27, 692], [690, 693], [689, 694], [696, 699], [-1], [-1], [695, 688], [-1], [704, 706], [707, 720], [709, 710], [711, 712], [713, 714], [715, 716], [718, 721], [724, 723], [725, 726], [193, 727], [732, 731], [733, 734], [431, 735], [736, 748], [738, 744], [746, 749], [745, 747], [740, 754], [743, 750], [752, 755], [751, 753], [114, 758], [756, 759], [111, 762], [760 ...

# %%
cnt=0
for i in connector_next:
    cnt+=len(i)
print(cnt)
# Out:
# 1808

# %%
import queue
print("start bfs")

print(len(pipe_next),len(connector_next))
print(len(endpoint_pipe),len(endpoint_connector))

# using list to record idx of pipe and connector we already visited
visited=list()
# all path with idx
paths=list()

visited_connector=list()
for i in range(0,len(distance[0])):
    visited_connector.append(0)
visited_pipe=list()
for i in range(0,len(distance)):
    visited_pipe.append(0)

ans=list()
q=queue.Queue()
start_idx=0
while(1):
    cur=-1
    while(start_idx<len(endpoint_pipe)):
        # print(endpoint_pipe[start_idx])
        if(visited_pipe[endpoint_pipe[start_idx]]==0):
            cur=endpoint_pipe[start_idx]
            break
        start_idx+=1
    # print("cur: ",cur)
    if(cur==-1):break
    q.put(cur)

    pipe_or_connector=1
    tmpans=list()
    
    # print("start again")
    while(q.qsize()>0):
        cur_qsize=q.qsize()
        print()
        # print(cur_qsize)
        # print(pipe_or_connector)
        # print(q.qsize())
        for i in range(0,cur_qsize):
            cur_idx=q.get()
            if(pipe_or_connector):
                # pipe
                if visited_pipe[cur_idx]:
                    continue

                # find pipe end
                if cur_idx%2:
                    cur_idx2=cur_idx-1
                else:
                    cur_idx2=cur_idx+1

                # endpoint_pipe.remove(cur_idx)
                tmpans.append([cur_idx,"pipe"])
                tmpans.append([cur_idx2,"pipe"])

                # print("encounter ",cur_idx," id: ",processor.src_pipe[cur_idx][3]," ",cur_idx2," id: ",processor.src_pipe[cur_idx2][3])

                visited_pipe[cur_idx]=1
                visited_pipe[cur_idx2]=1

                # if end is pipe
                if (cur_idx2 in endpoint_pipe):
                    continue
                
                # should append pipe start and end
                print("pipe ",cur_idx," ",cur_qsize)
                # print(pipe_next[cur_idx2][0])
                q.put(pipe_next[cur_idx2])
                print("pipe gen",pipe_next[cur_idx2])
                    
            else:
                # connector
                # print("yes")
                if visited_connector[cur_idx]:
                    continue
                visited_connector[cur_idx]=1
                # endpoint_connector.remove(cur_idx)
                tmpans.append([cur_idx,"connector"])

                print("connector ",cur_idx," ",cur_qsize)
                if(connector_next[cur_idx][0]!=-1):
                    for k in connector_next[cur_idx]:
                        print("connector produce",k)
                        q.put(k)

        if pipe_or_connector==1:
            pipe_or_connector=0
        else:
            pipe_or_connector=1
        
    ans.append(tmpans)

for i in ans:
    print(i)
anss=0
pipecnt=0
concnt=0
for i in ans:
    for j in i:
        if j[1]=="pipe": pipecnt+=1
        else: concnt+=1
print(pipecnt,concnt)
print(ans[0][0][0])
# Out:
# start bfs
# 2284 1276
# 513 385
#
# pipe  83   1
# pipe gen 55
#
# connector  55   1
# connector produce 82
# connector produce 85
#
# pipe  85   2
# pipe gen 54
#
# connector  54   1
# connector produce 79
# connector produce 84
#
# pipe  79   2
# pipe gen 53
#
# connector  53   1
# connector produce 78
# connector produce 81
#
# pipe  81   2
# pipe gen 52
#
# connector  52   1
# connector produce 75
# connector produce 80
#
# pipe  75   2
# pipe gen 51
#
# connector  51   1
# connector produce 74
# connector produce 77
#
# pipe  77   2
# pipe gen 50
#
# connector  50   1
# connector produce 73
# connector produce 76
#
# pipe  73   2
# pipe gen 49
#
# connector  49   1
# connector produce 69
# connector produce 72
#
# pipe  69   2
# pipe gen 48
#
# connector  48   1
# connector produce 68
# connector produce 71
#
# pipe  71   2
# pipe gen 47
#
# connector  47   1
# connector produce 70
# connector produce 2238
#
# pipe  2238   2
# pipe gen 1254
#
# connector  1254   1
# connector produce 2249
# connector produce 2239
#
# pipe  2249   2
# pipe gen 1253
#
# connector  1253   1
# connector produce 2200
# connector produce 2248
#
#
# pipe  108   1
# pipe gen 78
#
# connector  78   1
# connector produce 109
# connector produce 112
#
# pipe  112   2
# pipe gen 79
#
# connector  79   1
# connector produce 110
# connector produce 113
#
# pipe  110   2
# pipe gen 439
#
# connector  439   1
# connector produce 111
# connector produce 762
#
# pipe  762   2
# pipe gen 440
#
# connector  440   1
# connector produce 760
# connector produce 763
#
# pipe  760   2
# pipe gen 441
#
# connector  441   1
# connector produce 761
# connector produce 765
#
# pipe  765   2
# pipe gen 431
#
# connector  431   1
# connector produce 746
# connector produce 749
#
# pipe  746   2
# pipe gen 432
# pipe  749   2
# pipe gen 429
#
# connector  432   2
# connector produce 745
# connector produce 747
# connector  429   2
# connector produce 736
# connector produce 748
#
# pipe  745   4
# pipe gen 430
#
# connector  430   1
# connector produce 738
# connector produce 744
#
#
# pipe  117   1
# pipe gen 81
#
# connector  81   1
# connector produce 116
# connector produce 119
#
# pipe  119   2
# pipe gen 80
#
# connector  80   1
# connector produce 115
# connector produce 118
#
# pipe  115   2
# pipe gen 437
#
# connector  437   1
# connector produce 114
# connector produce 758
#
# pipe  758   2
# pipe gen 438
#
# connector  438   1
# connector produce 756
# connector produce 759
#
# pipe  756   2
# pipe gen 442
#
# connector  442   1
# connector produce 757
# connector produce 767
#
# pipe  767   2
# pipe gen 435
#
# connector  435   1
# connector produce 752
# connector produce 755
#
# pipe  752   2
# pipe gen 436
# pipe  755   2
# pipe gen 433
#
# connector  436   2
# connector produce 751
# connector produce 753
# connector  433   2
# connector produce 740
# connector produce 754
#
# pipe  751   4
# pipe gen 434
#
# connector  434   1
# connector produce 743
# connector produce 750
#
#
# pipe  133   1
# pipe gen 87
#
# connector  87   1
# connector produce 132
# connector produce 135
#
# pipe  135   2
# pipe gen 86
#
# connector  86   1
# connector produce 129
# connector produce 134
#
# pipe  129   2
# pipe gen 85
#
# connector  85   1
# connector produce 128
# connector produce 131
#
# pipe  131   2
# pipe gen 84
#
# connector  84   1
# connector produce 123
# connector produce 130
#
# pipe  123   2
# pipe gen 449
#
# connector  449   1
# connector produce 122
# connector produce 777
#
# pipe  777   2
# pipe gen 448
#
# connector  448   1
# connector produce 773
# connector produce 776
#
# pipe  773   2
# pipe gen 446
#
# connector  446   1
# connector produce 142
# connector produce 772
#
# pipe  142   2
# pipe gen 455
#
# connector  455   1
# connector produce 143
# connector produce 791
#
# pipe  791   2
# pipe gen 454
#
# connector  454   1
# connector produce 783
# connector produce 790
#
# pipe  783   2
# pipe gen 458
#
# connector  458   1
# connector produce 796
# connector produce 782
#
# pipe  796   2
# pipe gen 459
#
# connector  459   1
# connector produce 787
# connector produce 797
#
# pipe  787   2
# pipe gen 460
#
# connector  460   1
# connector produce 804
# connector produce 786
#
# pipe  804   2
# pipe gen 462
#
# connector  462   1
# connector produce 806
# connector produce 805
#
# pipe  806   2
# pipe gen 463
#
# connector  463   1
# connector produce 809
# connector produce 807
#
# pipe  809   2
# pipe gen 463
#
#
# pipe  137   1
# pipe gen 89
#
# connector  89   1
# connector produce 136
# connector produce 139
#
# pipe  139   2
# pipe gen 88
#
# connector  88   1
# connector produce 125
# connector produce 138
#
# pipe  125   2
# pipe gen 83
#
# connector  83   1
# connector produce 124
# connector produce 127
#
# pipe  127   2
# pipe gen 82
#
# connector  82   1
# connector produce 120
# connector produce 126
#
# pipe  120   2
# pipe gen 451
#
# connector  451   1
# connector produce 121
# connector produce 779
#
# pipe  779   2
# pipe gen 450
#
# connector  450   1
# connector produce 775
# connector produce 778
#
# pipe  775   2
# pipe gen 447
#
# connector  447   1
# connector produce 140
# connector produce 774
#
# pipe  140   2
# pipe gen 453
#
# connector  453   1
# connector produce 141
# connector produce 789
#
# pipe  789   2
# pipe gen 452
#
# connector  452   1
# connector produce 781
# connector produce 788
#
# pipe  781   2
# pipe gen 456
#
# connector  456   1
# connector produce 792
# connector produce 780
#
# pipe  792   2
# pipe gen 457
#
# connector  457   1
# connector produce 785
# connector produce 793
#
# pipe  785   2
# pipe gen 461
#
# connector  461   1
# connector produce 810
# connector produce 784
#
# pipe  810   2
# pipe gen 464
#
# connector  464   1
# connector produce 812
# connector produce 811
#
# pipe  812   2
# pipe gen 465
#
# connector  465   1
# connector produce 813
# connector produce 815
#
# pipe  815   2
# pipe gen 465
#
#
#
#
# pipe  219   1
# pipe gen 607
#
# connector  607   1
# connector produce 218
# connector produce 1159
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pipe  310   1
# pipe gen 287
#
# connector  287   1
# connector produce 311
# connector produce 321
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pipe  505   1
# pipe gen 286
#
# connector  286   1
# connector produce 504
# connector produce 2113
#
#
#
#
#
#
#
#
# pipe  519   1
# pipe gen 292
#
# connector  292   1
# connector produce 518
# connector produce 2140
#
#
#
# pipe  525   1
# pipe gen 295
#
# connector  295   1
# connector produce 524
# connector produce 527
#
#
# pipe  529   1
# pipe gen 296
#
# connector  296   1
# connector produce 528
# connector produce 510
#
#
#
#
#
#
#
#
# pipe  546   1
# pipe gen 310
#
# connector  310   1
#
# pipe  548   1
# pipe gen 312
#
# connector  312   1
#
# pipe  550   1
# pipe gen 311
#
# connector  311   1
# connector produce 448
# connector produce 551
#
# pipe  448   2
# pipe gen 265
#
# connector  265   1
# connector produce 449
# connector produce 450
#
# pipe  450   2
# pipe gen 323
#
# connector  323   1
# connector produce 451
# connector produce 570
#
# pipe  570   2
# pipe gen 324
#
# connector  324   1
# connector produce 571
# connector produce 568
#
#
# pipe  552   1
# pipe gen 313
#
# connector  313   1
# connector produce 553
# connector produce 446
#
# pipe  446   2
# pipe gen 349
#
# connector  349   1
# connector produce 627
# connector produce 447
#
# pipe  627   2
# pipe gen 321
#
# connector  321   1
# connector produce 566
# connector produce 626
#
# pipe  566   2
# pipe gen 322
#
# connector  322   1
# connector produce 567
# connector produce 564
#
#
#
#
#
#
#
#
# pipe  574   1
# pipe gen 327
#
# connector  327   1
#
# pipe  576   1
# pipe gen 336
#
# connector  336   1
# connector produce 577
# connector produce 601
#
# pipe  601   2
# pipe gen 335
#
# connector  335   1
# connector produce 600
# connector produce 599
#
# pipe  599   2
# pipe gen 106
#
# connector  106   1
# connector produce 174
# connector produce 170
#
# pipe  174   2
# pipe gen 107
# pipe  170   2
# pipe gen 337
#
# connector  107   2
# connector produce 175
# connector produce 184
# connector  337   2
# connector produce 602
# connector produce 171
#
# pipe  184   4
# pipe gen 110
# pipe  602   4
# pipe gen 338
#
# connector  110   2
# connector produce 182
# connector produce 172
# connector  338   2
# connector produce 595
# connector produce 603
#
# pipe  182   4
# pipe gen 111
# pipe  172   4
# pipe gen 108
#
# connector  111   2
# connector produce 180
# connector produce 183
# connector  108   2
# connector produce 173
# connector produce 178
#
# pipe  180   4
# pipe gen 305
# pipe  178   4
# pipe gen 109
#
# connector  305   2
# connector produce 540
# connector produce 181
# connector  109   2
# connector produce 176
# connector produce 179
#
# pipe  540   4
# pipe gen 304
# pipe  176   4
# pipe gen 294
#
# connector  304   2
# connector produce 541
# connector produce 543
# connector  294   2
# connector produce 523
# connector produce 177
#
# pipe  523   4
# pipe gen 293
#
# connector  293   1
# connector produce 522
# connector produce 526
#
#
#
#
#
#
# pipe  592   1
# pipe gen 333
#
# connector  333   1
#
#
# pipe  613   1
# pipe gen 344
#
# connector  344   1
# connector produce 612
# connector produce 615
#
# pipe  615   2
# pipe gen 343
#
# connector  343   1
# connector produce 609
# connector produce 614
#
# pipe  609   2
# pipe gen 342
#
# connector  342   1
# connector produce 608
# connector produce 611
#
# pipe  611   2
# pipe gen 341
#
# connector  341   1
# connector produce 607
# connector produce 610
#
# pipe  607   2
# pipe gen 158
#
# connector  158   1
# connector produce 296
# connector produce 606
#
# pipe  296   2
# pipe gen 159
#
# connector  159   1
# connector produce 294
# connector produce 297
#
# pipe  294   2
# pipe gen 289
#
# connector  289   1
#
# pipe  619   1
# pipe gen 347
#
# connector  347   1
# connector produce 618
# connector produce 621
#
# pipe  621   2
# pipe gen 346
#
# connector  346   1
# connector produce 617
# connector produce 620
#
# pipe  617   2
# pipe gen 345
#
# connector  345   1
# connector produce 616
# connector produce 628
#
# pipe  628   2
# pipe gen 350
#
# connector  350   1
# connector produce 629
# connector produce 622
#
# pipe  622   2
# pipe gen 348
#
# connector  348   1
# connector produce 623
# connector produce 625
#
# pipe  625   2
# pipe gen 1206
#
# connector  1206   1
# connector produce 624
# connector produce 2125
#
#
# pipe  630   1
# pipe gen 351
#
# connector  351   1
# connector produce 631
# connector produce 632
#
# pipe  632   2
# pipe gen 352
#
# connector  352   1
# connector produce 633
# connector produce 634
#
#
# pipe  636   1
# pipe gen 353
#
# connector  353   1
# connector produce 637
# connector produce 638
#
# pipe  638   2
# pipe gen 354
#
# connector  354   1
# connector produce 639
# connector produce 640
#
#
# pipe  647   1
# pipe gen 386
#
# connector  386   1
# connector produce 273
# connector produce 646
#
# pipe  273   2
# pipe gen 147
#
# connector  147   1
# connector produce 271
# connector produce 272
#
# pipe  271   2
# pipe gen 383
#
# connector  383   1
# connector produce 270
# connector produce 644
#
# pipe  644   2
# pipe gen 384
#
# connector  384   1
# connector produce 642
# connector produce 645
#
# pipe  642   2
# pipe gen 385
#
# connector  385   1
# connector produce 643
# connector produce 269
#
# pipe  269   2
# pipe gen 149
#
# connector  149   1
# connector produce 268
# connector produce 278
#
# pipe  278   2
# pipe gen 150
#
# connector  150   1
# connector produce 274
# connector produce 279
#
# pipe  274   2
# pipe gen 151
#
# connector  151   1
# connector produce 275
# connector produce 277
#
# pipe  277   2
# pipe gen 148
#
# connector  148   1
# connector produce 267
# connector produce 276
#
# pipe  267   2
# pipe gen 146
#
# connector  146   1
# connector produce 265
# connector produce 266
#
# pipe  265   2
# pipe gen 156
#
# connector  156   1
# connector produce 264
# connector produce 292
#
# pipe  292   2
# pipe gen 157
#
# connector  157   1
# connector produce 290
# connector produce 293
#
# pipe  290   2
# pipe gen 154
#
# connector  154   1
# connector produce 286
# connector produce 291
#
# pipe  286   2
# pipe gen 155
#
# connector  155   1
# connector produce 284
# connector produce 287
#
# pipe  284   2
# pipe gen 303
#
# connector  303   1
# connector produce 285
# connector produce 539
#
# pipe  539   2
# pipe gen 1204
#
# connector  1204   1
# connector produce 538
# connector produce 2123
#
#
# pipe  653   1
# pipe gen 390
#
# connector  390   1
# connector produce 401
# connector produce 652
#
# pipe  401   2
# pipe gen 209
#
# connector  209   1
# connector produce 399
# connector produce 400
#
# pipe  399   2
# pipe gen 387
#
# connector  387   1
# connector produce 398
# connector produce 650
#
# pipe  650   2
# pipe gen 388
#
# connector  388   1
# connector produce 648
# connector produce 651
#
# pipe  648   2
# pipe gen 389
#
# connector  389   1
# connector produce 397
# connector produce 649
#
# pipe  397   2
# pipe gen 211
#
# connector  211   1
# connector produce 396
# connector produce 406
#
# pipe  406   2
# pipe gen 212
#
# connector  212   1
# connector produce 402
# connector produce 407
#
# pipe  402   2
# pipe gen 213
#
# connector  213   1
# connector produce 403
# connector produce 405
#
# pipe  405   2
# pipe gen 210
#
# connector  210   1
# connector produce 395
# connector produce 404
#
# pipe  395   2
# pipe gen 208
#
# connector  208   1
# connector produce 393
# connector produce 394
#
# pipe  393   2
# pipe gen 214
#
# connector  214   1
# connector produce 392
# connector produce 410
#
# pipe  410   2
# pipe gen 215
#
# connector  215   1
# connector produce 408
# connector produce 411
#
# pipe  408   2
# pipe gen 924
#
# connector  924   1
# connector produce 1755
# connector produce 1753
#
# pipe  1755   2
# pipe gen 924
# pipe  1753   2
# pipe gen 926
#
# connector  926   2
# connector produce 1761
# connector produce 2218
#
# pipe  1761   2
# pipe gen 925
# pipe  2218   2
# pipe gen 1240
#
# connector  925   2
# connector produce 1756
# connector produce 1760
# connector  1240   2
# connector produce 100
# connector produce 2219
#
# pipe  1756   4
# pipe gen 926
# pipe  100   4
# pipe gen 67
#
# connector  67   2
# connector produce 98
# connector produce 101
#
# pipe  98   2
# pipe gen 68
#
# connector  68   1
# connector produce 94
# connector produce 99
#
# pipe  94   2
# pipe gen 69
#
# connector  69   1
# connector produce 95
# connector produce 97
#
# pipe  97   2
# pipe gen 66
#
# connector  66   1
# connector produce 88
# connector produce 96
#
# pipe  88   2
# pipe gen 64
#
# connector  64   1
# connector produce 89
# connector produce 92
#
# pipe  92   2
# pipe gen 65
#
# connector  65   1
# connector produce 90
# connector produce 93
#
# pipe  90   2
# pipe gen 443
#
# connector  443   1
# connector produce 91
# connector produce 770
#
# pipe  770   2
# pipe gen 444
#
# connector  444   1
# connector produce 768
# connector produce 771
#
# pipe  768   2
# pipe gen 445
#
# connector  445   1
# connector produce 769
# connector produce 691
#
# pipe  691   2
# pipe gen 409
#
# connector  409   1
# connector produce 690
# connector produce 693
#
# pipe  693   2
# pipe gen 408
#
# connector  408   1
# connector produce 27
# connector produce 692
#
# pipe  27   2
# pipe gen 27
#
# connector  27   1
# connector produce 26
# connector produce 29
#
# pipe  29   2
# pipe gen 26
#
# connector  26   1
# connector produce 28
# connector produce 964
#
# pipe  964   2
# pipe gen 514
#
# connector  514   1
# connector produce 25
# connector produce 965
#
# pipe  25   2
# pipe gen 25
#
# connector  25   1
# connector produce 21
# connector produce 24
#
# pipe  21   2
# pipe gen 24
#
# connector  24   1
# connector produce 20
# connector produce 23
#
# pipe  23   2
# pipe gen 23
#
# connector  23   1
# connector produce 19
# connector produce 22
#
# pipe  19   2
# pipe gen 22
#
# connector  22   1
# connector produce 15
# connector produce 18
#
# pipe  15   2
# pipe gen 21
#
# connector  21   1
# connector produce 14
# connector produce 17
#
# pipe  17   2
# pipe gen 20
#
# connector  20   1
# connector produce 16
# connector produce 2228
#
# pipe  2228   2
# pipe gen 1246
#
# connector  1246   1
# connector produce 2230
# connector produce 2229
#
# pipe  2230   2
# pipe gen 1249
#
# connector  1249   1
# connector produce 2231
# connector produce 2241
#
# pipe  2241   2
# pipe gen 1248
#
# connector  1248   1
# connector produce 2194
# connector produce 2240
#
#
#
#
#
#
#
# pipe  681   1
# pipe gen 404
#
# connector  404   1
# connector produce 680
# connector produce 682
#
# pipe  682   2
# pipe gen 405
#
# connector  405   1
# connector produce 683
# connector produce 684
#
# pipe  684   2
# pipe gen 406
#
# connector  406   1
# connector produce 685
# connector produce 686
#
# pipe  686   2
# pipe gen 407
#
# connector  407   1
# connector produce 687
# connector produce 698
#
# pipe  698   2
# pipe gen 411
#
# connector  411   1
# connector produce 696
# connector produce 699
#
# pipe  696   2
# pipe gen 703
#
# connector  703   1
# connector produce 700
# connector produce 697
#
# pipe  700   2
# pipe gen 706
#
# connector  706   1
# connector produce 701
# connector produce 1365
#
# pipe  1365   2
# pipe gen 705
#
# connector  705   1
# connector produce 1367
# connector produce 1364
#
# pipe  1367   2
# pipe gen 704
#
# connector  704   1
# connector produce 439
# connector produce 1366
#
# pipe  439   2
# pipe gen 700
#
# connector  700   1
# connector produce 438
# connector produce 1362
#
# pipe  1362   2
# pipe gen 701
#
# connector  701   1
# connector produce 1363
# connector produce 1360
#
# pipe  1360   2
# pipe gen 702
#
# connector  702   1
# connector produce 1358
# connector produce 1361
#
# pipe  1358   2
# pipe gen 698
#
# connector  698   1
# connector produce 1356
# connector produce 1359
#
# pipe  1356   2
# pipe gen 699
#
# connector  699   1
# connector produce 1354
# connector produce 1357
#
# pipe  1354   2
# pipe gen 695
#
# connector  695   1
# connector produce 1352
# connector produce 1355
#
# pipe  1352   2
# pipe gen 696
#
# connector  696   1
#
# pipe  705   1
# pipe gen 416
#
# connector  416   1
# connector produce 704
# connector produce 706
#
# pipe  706   2
# pipe gen 417
#
# connector  417   1
# connector produce 707
# connector produce 720
#
# pipe  720   2
# pipe gen 422
#
# connector  422   1
# connector produce 718
# connector produce 721
#
# pipe  718   2
# pipe gen 707
#
# connector  707   1
# connector produce 728
# connector produce 719
#
# pipe  728   2
# pipe gen 717
#
# connector  717   1
# connector produce 729
# connector produce 1384
#
# pipe  1384   2
# pipe gen 718
#
# connector  718   1
# connector produce 1382
# connector produce 1385
#
# pipe  1382   2
# pipe gen 715
#
# connector  715   1
# connector produce 1383
# connector produce 1380
#
# pipe  1380   2
# pipe gen 716
#
# connector  716   1
# connector produce 1378
# connector produce 1381
#
# pipe  1378   2
# pipe gen 713
#
# connector  713   1
# connector produce 1379
# connector produce 1376
#
# pipe  1376   2
# pipe gen 714
#
# connector  714   1
# connector produce 1375
# connector produce 1377
#
# pipe  1375   2
# pipe gen 712
#
# connector  712   1
# connector produce 437
# connector produce 1374
#
# pipe  437   2
# pipe gen 709
#
# connector  709   1
# connector produce 436
# connector produce 1372
#
# pipe  1372   2
# pipe gen 710
#
# connector  710   1
# connector produce 1373
# connector produce 1370
#
# pipe  1370   2
# pipe gen 711
#
# connector  711   1
# connector produce 1369
# connector produce 249
#
# pipe  1369   2
# pipe gen 708
#
# connector  708   1
# connector produce 1368
# connector produce 1371
#
#
# pipe  717   1
# pipe gen 421
#
# connector  421   1
# connector produce 715
# connector produce 716
#
# pipe  715   2
# pipe gen 420
#
# connector  420   1
# connector produce 713
# connector produce 714
#
# pipe  713   2
# pipe gen 419
#
# connector  419   1
# connector produce 711
# connector produce 712
#
# pipe  711   2
# pipe gen 418
#
# connector  418   1
# connector produce 709
# connector produce 710
#
# pipe  709   2
# pipe gen 423
#
# connector  423   1
# connector produce 724
# connector produce 723
#
# pipe  724   2
# pipe gen 424
# pipe  723   2
# pipe gen 426
#
# connector  424   2
# connector produce 725
# connector produce 726
# connector  426   2
# connector produce 732
# connector produce 731
#
# pipe  726   4
# pipe gen 425
# pipe  732   4
# pipe gen 427
# pipe  731   4
# pipe gen 422
#
# connector  425   3
# connector produce 193
# connector produce 727
# connector  427   3
# connector produce 733
# connector produce 734
#
# pipe  193   4
# pipe gen 115
# pipe  734   4
# pipe gen 428
#
# connector  115   2
# connector produce 192
# connector produce 195
# connector  428   2
# connector produce 431
# connector produce 735
#
# pipe  195   4
# pipe gen 114
# pipe  431   4
# pipe gen 241
#
# connector  114   2
# connector produce 189
# connector produce 194
# connector  241   2
# connector produce 430
# connector produce 433
#
# pipe  189   4
# pipe gen 113
# pipe  433   4
# pipe gen 240
#
# connector  113   2
# connector produce 188
# connector produce 191
# connector  240   2
# connector produce 427
# connector produce 432
#
# pipe  191   4
# pipe gen 124
# pipe  427   4
# pipe gen 239
#
# connector  124   2
# connector produce 190
# connector produce 213
# connector  239   2
# connector produce 426
# connector produce 429
#
# pipe  213   4
# pipe gen 123
# pipe  429   4
# pipe gen 238
#
# connector  123   2
# connector produce 212
# connector produce 215
# connector  238   2
# connector produce 423
# connector produce 428
#
# pipe  215   4
# pipe gen 122
# pipe  423   4
# pipe gen 237
#
# connector  122   2
# connector produce 214
# connector produce 211
# connector  237   2
# connector produce 422
# connector produce 425
#
# pipe  211   4
# pipe gen 117
# pipe  425   4
# pipe gen 236
#
# connector  117   2
# connector produce 202
# connector produce 210
# connector  236   2
# connector produce 421
# connector produce 424
#
# pipe  202   4
# pipe gen 118
# pipe  421   4
# pipe gen 232
#
# connector  118   2
# connector produce 198
# connector produce 203
# connector  232   2
# connector produce 416
# connector produce 420
#
# pipe  198   4
# pipe gen 119
# pipe  416   4
# pipe gen 235
#
# connector  119   2
# connector produce 199
# connector produce 201
# connector  235   2
# connector produce 415
# connector produce 417
#
# pipe  201   4
# pipe gen 116
# pipe  415   4
# pipe gen 234
#
# connector  116   2
# connector produce 200
# connector produce 197
# connector  234   2
# connector produce 414
# connector produce 419
#
# pipe  197   4
# pipe gen 112
# pipe  419   4
# pipe gen 233
#
# connector  112   2
# connector produce 187
# connector produce 196
# connector  233   2
# connector produce 412
# connector produce 418
#
# pipe  187   4
# pipe gen 120
# pipe  412   4
# pipe gen 1031
#
# connector  120   2
# connector produce 186
# connector produce 206
# connector  1031   2
#
# pipe  206   2
# pipe gen 121
#
# connector  121   1
# connector produce 204
# connector produce 207
#
# pipe  204   2
# pipe gen 280
#
# connector  280   1
# connector produce 205
# connector produce 494
#
# pipe  494   2
# pipe gen 281
#
# connector  281   1
# connector produce 492
# connector produce 495
#
# pipe  492   2
# pipe gen 1209
#
# connector  1209   1
# connector produce 493
# connector produce 2129
#
# pipe  2129   2
# pipe gen 1208
#
# connector  1208   1
# connector produce 2128
# connector produce 2131
#
#
# pipe  794   1
# pipe gen 456
#
#
# pipe  798   1
# pipe gen 458
#
#
# pipe  800   1
# pipe gen 460
#
#
# pipe  802   1
# pipe gen 461
#
#
# pipe  821   1
# pipe gen 467
#
# connector  467   1
# connector produce 820
# connector produce 819
#
# pipe  819   2
# pipe gen 468
#
# connector  468   1
# connector produce 822
# connector produce 825
#
# pipe  822   2
# pipe gen 468
# pipe  825   2
# pipe gen 466
#
# connector  466   2
# connector produce 824
# connector produce 817
#
# pipe  817   2
# pipe gen 466
#
#
# pipe  831   1
# pipe gen 470
#
# connector  470   1
# connector produce 829
# connector produce 830
#
# pipe  829   2
# pipe gen 471
#
# connector  471   1
# connector produce 832
# connector produce 835
#
# pipe  832   2
# pipe gen 471
# pipe  835   2
# pipe gen 469
#
# connector  469   2
# connector produce 827
# connector produce 834
#
# pipe  827   2
# pipe gen 469
#
#
# pipe  837   1
# pipe gen 475
#
# connector  475   1
# connector produce 836
# connector produce 845
#
# pipe  845   2
# pipe gen 474
#
# connector  474   1
# connector produce 844
# connector produce 838
#
# pipe  838   2
# pipe gen 472
#
# connector  472   1
# connector produce 839
# connector produce 842
#
# pipe  842   2
# pipe gen 473
#
# connector  473   1
# connector produce 841
# connector produce 843
#
# pipe  841   2
# pipe gen 198
#
# connector  198   1
# connector produce 840
# connector produce 389
#
# pipe  389   2
# pipe gen 197
#
# connector  197   1
# connector produce 388
# connector produce 381
#
# pipe  381   2
# pipe gen 194
#
# connector  194   1
# connector produce 383
# connector produce 380
#
# pipe  383   2
# pipe gen 193
#
# connector  193   1
# connector produce 374
# connector produce 382
#
# pipe  374   2
# pipe gen 190
#
# connector  190   1
# connector produce 375
# connector produce 378
#
# pipe  378   2
# pipe gen 191
#
# connector  191   1
# connector produce 376
# connector produce 379
#
# pipe  376   2
# pipe gen 192
#
# connector  192   1
# connector produce 364
# connector produce 377
#
# pipe  364   2
# pipe gen 184
#
# connector  184   1
# connector produce 362
# connector produce 365
#
# pipe  362   2
# pipe gen 185
#
# connector  185   1
# connector produce 368
# connector produce 363
#
# pipe  368   2
# pipe gen 186
#
# connector  186   1
# connector produce 366
# connector produce 369
#
# pipe  366   2
# pipe gen 187
#
# connector  187   1
# connector produce 349
# connector produce 367
#
# pipe  349   2
# pipe gen 179
#
# connector  179   1
# connector produce 348
# connector produce 351
#
# pipe  351   2
# pipe gen 178
#
# connector  178   1
# connector produce 346
# connector produce 353
#
# pipe  346   2
# pipe gen 175
# pipe  353   2
# pipe gen 660
#
# connector  175   2
# connector produce 338
# connector produce 347
# connector  660   2
# connector produce 352
# connector produce 1270
#
# pipe  338   4
# pipe gen 173
# pipe  1270   4
# pipe gen 661
#
# connector  173   2
# connector produce 336
# connector produce 587
# connector  661   2
# connector produce 1271
# connector produce 158
#
# pipe  336   4
# pipe gen 174
# pipe  587   4
# pipe gen 330
# pipe  158   4
# pipe gen 1197
#
# connector  174   3
# connector produce 334
# connector produce 337
# connector  330   3
# connector produce 586
# connector produce 589
# connector  1197   3
# connector produce 159
# connector produce 167
#
# pipe  334   6
# pipe gen 1260
# pipe  589   6
# pipe gen 329
# pipe  167   6
# pipe gen 99
#
# connector  1260   3
# connector produce 335
# connector produce 2262
# connector  329   3
# connector produce 588
# connector produce 591
# connector  99   3
# connector produce 166
# connector produce 169
#
# pipe  2262   6
# pipe gen 1261
# pipe  169   6
# pipe gen 98
#
# connector  1261   2
# connector produce 2260
# connector produce 2263
# connector  98   2
# connector produce 160
# connector produce 168
#
# pipe  2260   4
# pipe gen 1262
# pipe  160   4
# pipe gen 96
#
# connector  1262   2
# connector produce 581
# connector produce 2261
# connector  96   2
# connector produce 161
# connector produce 164
#
# pipe  581   4
# pipe gen 328
# pipe  164   4
# pipe gen 97
#
# connector  328   2
# connector produce 580
# connector produce 583
# connector  97   2
# connector produce 162
# connector produce 165
#
# pipe  162   4
# pipe gen 340
#
# connector  340   1
# connector produce 163
# connector produce 605
#
# pipe  605   2
# pipe gen 339
#
# connector  339   1
# connector produce 557
# connector produce 545
#
#
# pipe  846   1
# pipe gen 474
#
#
# pipe  849   1
# pipe gen 477
#
# connector  477   1
# connector produce 848
# connector produce 853
#
# pipe  853   2
# pipe gen 476
#
# connector  476   1
# connector produce 852
# connector produce 850
#
# pipe  850   2
# pipe gen 478
#
# connector  478   1
# connector produce 851
# connector produce 858
#
# pipe  858   2
# pipe gen 479
#
# connector  479   1
# connector produce 857
# connector produce 859
#
# pipe  857   2
# pipe gen 200
#
# connector  200   1
# connector produce 391
# connector produce 856
#
# pipe  391   2
# pipe gen 199
#
# connector  199   1
# connector produce 390
# connector produce 385
#
# pipe  385   2
# pipe gen 196
#
# connector  196   1
# connector produce 384
# connector produce 387
#
# pipe  387   2
# pipe gen 195
#
# connector  195   1
# connector produce 386
# connector produce 371
#
# pipe  371   2
# pipe gen 189
#
# connector  189   1
# connector produce 373
# connector produce 370
#
# pipe  373   2
# pipe gen 188
#
# connector  188   1
# connector produce 372
# connector produce 354
#
# pipe  354   2
# pipe gen 180
#
# connector  180   1
# connector produce 358
# connector produce 355
#
# pipe  358   2
# pipe gen 183
#
# connector  183   1
# connector produce 357
# connector produce 359
#
# pipe  357   2
# pipe gen 182
#
# connector  182   1
# connector produce 356
# connector produce 361
#
# pipe  361   2
# pipe gen 181
#
# connector  181   1
# connector produce 360
# connector produce 340
#
# pipe  340   2
# pipe gen 177
#
# connector  177   1
# connector produce 343
# connector produce 341
#
# pipe  343   2
# pipe gen 176
#
# connector  176   1
# connector produce 342
# connector produce 345
#
# pipe  345   2
# pipe gen 175
#
#
# pipe  854   1
# pipe gen 476
#
#
# pipe  865   1
# pipe gen 481
#
# connector  481   1
# connector produce 864
# connector produce 863
#
# pipe  863   2
# pipe gen 482
#
# connector  482   1
# connector produce 866
# connector produce 869
#
# pipe  866   2
# pipe gen 482
# pipe  869   2
# pipe gen 480
#
# connector  480   2
# connector produce 861
# connector produce 868
#
# pipe  861   2
# pipe gen 480
#
#
# pipe  875   1
# pipe gen 484
#
# connector  484   1
# connector produce 874
# connector produce 873
#
# pipe  873   2
# pipe gen 485
#
# connector  485   1
# connector produce 876
# connector produce 879
#
# pipe  876   2
# pipe gen 485
# pipe  879   2
# pipe gen 483
#
# connector  483   2
# connector produce 871
# connector produce 878
#
# pipe  871   2
# pipe gen 483
#
#
# pipe  889   1
# pipe gen 488
#
# connector  488   1
# connector produce 883
# connector produce 888
#
# pipe  883   2
# pipe gen 487
#
# connector  487   1
# connector produce 882
# connector produce 885
#
# pipe  885   2
# pipe gen 486
#
# connector  486   1
# connector produce 884
# connector produce 887
#
# pipe  887   2
# pipe gen 489
#
# connector  489   1
# connector produce 886
# connector produce 890
#
# pipe  890   2
# pipe gen 490
#
# connector  490   1
# connector produce 891
# connector produce 896
#
#
# pipe  895   1
# pipe gen 492
#
# connector  492   1
# connector produce 893
# connector produce 894
#
# pipe  893   2
# pipe gen 491
#
# connector  491   1
# connector produce 881
# connector produce 892
#
# pipe  881   2
# pipe gen 486
#
#
# pipe  903   1
# pipe gen 494
#
# connector  494   1
# connector produce 899
# connector produce 902
#
# pipe  899   2
# pipe gen 493
#
# connector  493   1
# connector produce 898
# connector produce 901
#
# pipe  901   2
# pipe gen 496
#
# connector  496   1
# connector produce 907
# connector produce 900
#
# pipe  907   2
# pipe gen 495
#
# connector  495   1
# connector produce 904
# connector produce 906
#
#
# pipe  911   1
# pipe gen 497
#
# connector  497   1
# connector produce 910
# connector produce 908
#
# pipe  908   2
# pipe gen 496
#
#
# pipe  914   1
# pipe gen 498
#
# connector  498   1
# connector produce 915
# connector produce 912
#
# pipe  912   2
# pipe gen 497
#
#
# pipe  920   1
# pipe gen 500
#
# connector  500   1
# connector produce 919
# connector produce 921
#
# pipe  919   2
# pipe gen 499
#
# connector  499   1
# connector produce 917
# connector produce 918
#
# pipe  917   2
# pipe gen 501
#
# connector  501   1
# connector produce 922
# connector produce 916
#
# pipe  922   2
# pipe gen 502
#
# connector  502   1
# connector produce 923
# connector produce 926
#
#
# pipe  929   1
# pipe gen 503
#
# connector  503   1
# connector produce 928
# connector produce 932
#
# pipe  932   2
# pipe gen 504
#
# connector  504   1
# connector produce 930
# connector produce 924
#
# pipe  924   2
# pipe gen 501
#
#
#
#
#
#
#
#
#
#
#
#
#
# pipe  957   1
# pipe gen 512
#
# connector  512   1
# connector produce 960
# connector produce 963
#
# pipe  960   2
# pipe gen 513
#
# connector  513   1
# connector produce 959
# connector produce 961
#
#
#
#
#
#
# pipe  983   1
# pipe gen 520
#
# connector  520   1
# connector produce 979
# connector produce 982
#
# pipe  979   2
# pipe gen 521
#
# connector  521   1
# connector produce 984
# connector produce 978
#
#
# pipe  989   1
# pipe gen 523
#
# connector  523   1
# connector produce 988
# connector produce 991
#
# pipe  991   2
# pipe gen 522
#
# connector  522   1
# connector produce 974
# connector produce 990
#
# pipe  974   2
# pipe gen 517
#
# connector  517   1
# connector produce 975
# connector produce 976
#
# pipe  976   2
# pipe gen 518
#
# connector  518   1
# connector produce 977
# connector produce 980
#
# pipe  980   2
# pipe gen 519
#
# connector  519   1
# connector produce 981
# connector produce 986
#
# pipe  986   2
# pipe gen 521
#
#
# pipe  993   1
# pipe gen 524
#
# connector  524   1
# connector produce 992
# connector produce 996
#
# pipe  996   2
# pipe gen 525
#
# connector  525   1
# connector produce 994
# connector produce 997
#
# pipe  994   2
# pipe gen 526
#
# connector  526   1
# connector produce 995
# connector produce 1020
#
# pipe  1020   2
# pipe gen 534
#
# connector  534   1
# connector produce 1018
# connector produce 1016
#
# pipe  1018   2
# pipe gen 535
# pipe  1016   2
# pipe gen 532
#
# connector  535   2
# connector produce 1019
# connector produce 1003
# connector  532   2
# connector produce 1014
# connector produce 998
#
# pipe  1003   4
# pipe gen 527
# pipe  1014   4
# pipe gen 533
# pipe  998   4
# pipe gen 531
#
# connector  527   3
# connector produce 1001
# connector produce 1002
# connector  533   3
# connector produce 1015
# connector produce 1007
# connector  531   3
# connector produce 999
# connector produce 1013
#
# pipe  1007   6
# pipe gen 528
# pipe  1013   6
# pipe gen 530
#
# connector  528   2
# connector produce 1005
# connector produce 1006
# connector  530   2
# connector produce 1011
# connector produce 1012
#
# pipe  1011   4
# pipe gen 529
#
# connector  529   1
# connector produce 1009
# connector produce 1010
#
#
# pipe  1035   1
# pipe gen 540
#
# connector  540   1
# connector produce 1034
# connector produce 1036
#
# pipe  1036   2
# pipe gen 548
#
# connector  548   1
# connector produce 1037
# connector produce 1060
#
# pipe  1060   2
# pipe gen 549
#
# connector  549   1
# connector produce 1023
# connector produce 1061
#
# pipe  1023   2
# pipe gen 538
#
# connector  538   1
# connector produce 1032
# connector produce 1022
#
# pipe  1032   2
# pipe gen 539
#
# connector  539   1
# connector produce 1026
# connector produce 1033
#
# pipe  1026   2
# pipe gen 537
#
# connector  537   1
# connector produce 1027
# connector produce 1029
#
# pipe  1029   2
# pipe gen 536
#
# connector  536   1
# connector produce 1028
# connector produce 1074
#
# pipe  1074   2
# pipe gen 556
#
# connector  556   1
# connector produce 1102
# connector produce 1024
#
# pipe  1102   2
# pipe gen 577
# pipe  1024   2
# pipe gen 555
#
# connector  577   2
# connector produce 1072
# connector produce 1103
# connector  555   2
# connector produce 1025
# connector produce 1071
#
# pipe  1072   4
# pipe gen 557
# pipe  1071   4
# pipe gen 580
#
# connector  557   2
# connector produce 1073
# connector produce 1053
# connector  580   2
# connector produce 1109
# connector produce 1070
#
# pipe  1053   4
# pipe gen 544
# pipe  1109   4
# pipe gen 554
#
# connector  544   2
# connector produce 1050
# connector produce 1052
# connector  554   2
# connector produce 1057
# connector produce 1108
#
# pipe  1057   4
# pipe gen 545
#
# connector  545   1
# connector produce 1054
# connector produce 1056
#
#
# pipe  1039   1
# pipe gen 541
#
# connector  541   1
# connector produce 1038
# connector produce 1040
#
# pipe  1040   2
# pipe gen 550
#
# connector  550   1
# connector produce 1041
# connector produce 1064
#
# pipe  1064   2
# pipe gen 551
#
# connector  551   1
# connector produce 1065
# connector produce 1062
#
# pipe  1062   2
# pipe gen 538
#
#
# pipe  1043   1
# pipe gen 542
#
# connector  542   1
# connector produce 1042
# connector produce 1044
#
# pipe  1044   2
# pipe gen 546
#
# connector  546   1
# connector produce 1045
# connector produce 1058
#
# pipe  1058   2
# pipe gen 547
#
# connector  547   1
# connector produce 1059
# connector produce 1066
#
# pipe  1066   2
# pipe gen 551
#
#
# pipe  1047   1
# pipe gen 543
#
# connector  543   1
# connector produce 1046
# connector produce 1048
#
# pipe  1048   2
# pipe gen 552
#
# connector  552   1
# connector produce 1049
# connector produce 1096
#
# pipe  1096   2
# pipe gen 574
#
# connector  574   1
# connector produce 1097
# connector produce 1068
#
# pipe  1068   2
# pipe gen 553
#
# connector  553   1
# connector produce 1030
# connector produce 1069
#
# pipe  1030   2
# pipe gen 536
#
#
# pipe  1110   1
# pipe gen 584
#
# connector  584   1
# connector produce 1111
# connector produce 1113
#
# pipe  1113   2
# pipe gen 588
#
# connector  588   1
# connector produce 1122
# connector produce 1125
#
# pipe  1122   2
# pipe gen 589
# pipe  1125   2
# pipe gen 583
#
# connector  589   2
# connector produce 1086
# connector produce 1123
# connector  583   2
# connector produce 1115
# connector produce 1124
#
# pipe  1086   4
# pipe gen 572
# pipe  1115   4
# pipe gen 582
#
# connector  572   2
# connector produce 1087
# connector produce 1088
# connector  582   2
# connector produce 1078
# connector produce 1114
#
# pipe  1088   4
# pipe gen 576
# pipe  1078   4
# pipe gen 569
#
# connector  576   2
# connector produce 1089
# connector produce 1098
# connector  569   2
# connector produce 1079
# connector produce 1080
#
# pipe  1098   4
# pipe gen 578
# pipe  1080   4
# pipe gen 570
#
# connector  578   2
# connector produce 1101
# connector produce 1099
# connector  570   2
# connector produce 1081
# connector produce 1082
#
# pipe  1101   4
# pipe gen 577
# pipe  1082   4
# pipe gen 571
#
# connector  571   2
# connector produce 1083
# connector produce 1084
#
# pipe  1084   2
# pipe gen 579
#
# connector  579   1
# connector produce 1085
# connector produce 1104
#
# pipe  1104   2
# pipe gen 581
#
# connector  581   1
# connector produce 1107
# connector produce 1105
#
# pipe  1107   2
# pipe gen 580
#
#
# pipe  1116   1
# pipe gen 587
#
# connector  587   1
# connector produce 1117
# connector produce 1119
#
# pipe  1119   2
# pipe gen 586
#
# connector  586   1
# connector produce 1118
# connector produce 1121
#
# pipe  1121   2
# pipe gen 585
#
# connector  585   1
# connector produce 1076
# connector produce 1120
#
# pipe  1076   2
# pipe gen 568
#
# connector  568   1
# connector produce 1077
# connector produce 1090
#
# pipe  1090   2
# pipe gen 573
#
# connector  573   1
# connector produce 1091
# connector produce 1092
#
# pipe  1092   2
# pipe gen 575
#
# connector  575   1
# connector produce 1095
# connector produce 1093
#
# pipe  1095   2
# pipe gen 574
#
#
# pipe  1129   1
# pipe gen 600
#
# connector  600   1
# connector produce 1128
# connector produce 1126
#
# pipe  1126   2
# pipe gen 601
#
# connector  601   1
# connector produce 1127
# connector produce 1132
#
#
# pipe  1135   1
# pipe gen 602
#
# connector  602   1
# connector produce 1130
# connector produce 1134
#
# pipe  1130   2
# pipe gen 600
#
#
# pipe  1139   1
# pipe gen 604
#
# connector  604   1
# connector produce 1138
# connector produce 1141
#
# pipe  1141   2
# pipe gen 603
#
# connector  603   1
# connector produce 1140
# connector produce 1146
#
# pipe  1146   2
# pipe gen 605
#
# connector  605   1
# connector produce 1144
# connector produce 1236
#
# pipe  1144   2
# pipe gen 606
# pipe  1236   2
# pipe gen 640
#
# connector  606   2
# connector produce 1142
# connector produce 1145
# connector  640   2
# connector produce 1234
# connector produce 1136
#
# pipe  1234   4
# pipe gen 641
# pipe  1136   4
# pipe gen 643
#
# connector  641   2
# connector produce 1232
# connector produce 1235
# connector  643   2
# connector produce 1137
# connector produce 1240
#
# pipe  1232   4
# pipe gen 642
# pipe  1240   4
# pipe gen 644
#
# connector  642   2
# connector produce 1231
# connector produce 1233
# connector  644   2
# connector produce 1238
# connector produce 1241
#
# pipe  1231   4
# pipe gen 639
# pipe  1238   4
# pipe gen 645
#
# connector  639   2
# connector produce 1227
# connector produce 1230
# connector  645   2
# connector produce 1220
# connector produce 1239
#
# pipe  1227   4
# pipe gen 638
# pipe  1220   4
# pipe gen 636
#
# connector  638   2
# connector produce 1226
# connector produce 1229
# connector  636   2
# connector produce 1221
# connector produce 1223
#
# pipe  1229   4
# pipe gen 637
# pipe  1223   4
# pipe gen 635
#
# connector  637   2
# connector produce 1151
# connector produce 1228
# connector  635   2
# connector produce 1222
# connector produce 1225
#
# pipe  1151   4
# pipe gen 664
# pipe  1225   4
# pipe gen 634
#
# connector  664   2
# connector produce 1286
# connector produce 1150
# connector  634   2
# connector produce 1224
# connector produce 1274
#
# pipe  1286   4
# pipe gen 667
# pipe  1274   4
# pipe gen 662
#
# connector  667   2
# connector produce 1284
# connector produce 1276
# connector  662   2
# connector produce 1282
# connector produce 1218
#
# pipe  1284   4
# pipe gen 611
# pipe  1276   4
# pipe gen 665
# pipe  1282   4
# pipe gen 666
# pipe  1218   4
# pipe gen 631
#
# connector  611   4
# connector produce 1168
# connector produce 1285
# connector  665   4
# connector produce 1153
# connector produce 1277
# connector  666   4
# connector produce 1280
# connector produce 1272
# connector  631   4
# connector produce 1216
# connector produce 1278
#
# pipe  1168   8
# pipe gen 612
# pipe  1280   8
# pipe gen 608
# pipe  1272   8
# pipe gen 663
# pipe  1216   8
# pipe gen 632
# pipe  1278   8
# pipe gen 664
#
# connector  612   5
# connector produce 1166
# connector produce 1169
# connector  608   5
# connector produce 1162
# connector produce 1281
# connector  663   5
# connector produce 1155
# connector produce 1273
# connector  632   5
# connector produce 1214
# connector produce 1217
#
# pipe  1166   8
# pipe gen 613
# pipe  1162   8
# pipe gen 609
# pipe  1214   8
# pipe gen 633
#
# connector  613   3
# connector produce 1167
# connector produce 1174
# connector  609   3
# connector produce 1163
# connector produce 1178
# connector  633   3
# connector produce 1149
# connector produce 1215
#
# pipe  1174   6
# pipe gen 616
# pipe  1178   6
# pipe gen 614
# pipe  1149   6
# pipe gen 628
#
# connector  616   3
# connector produce 1173
# connector produce 1175
# connector  614   3
# connector produce 1176
# connector produce 1160
# connector  628   3
# connector produce 1210
# connector produce 1148
#
# pipe  1173   6
# pipe gen 615
# pipe  1176   6
# pipe gen 615
# pipe  1160   6
# pipe gen 610
# pipe  1210   6
# pipe gen 629
#
# connector  615   4
# connector produce 1172
# connector produce 1177
# connector  610   4
# connector produce 1157
# connector produce 1161
# connector  629   4
# connector produce 1206
# connector produce 1211
#
# pipe  1157   6
# pipe gen 607
# pipe  1206   6
# pipe gen 630
#
# connector  630   2
# connector produce 1207
# connector produce 1209
#
# pipe  1209   2
# pipe gen 627
#
# connector  627   1
# connector produce 1204
# connector produce 1208
#
#
# pipe  1185   1
# pipe gen 620
#
# connector  620   1
# connector produce 1184
# connector produce 1187
#
# pipe  1187   2
# pipe gen 619
#
# connector  619   1
# connector produce 1181
# connector produce 1186
#
# pipe  1181   2
# pipe gen 618
#
# connector  618   1
# connector produce 1180
# connector produce 1183
#
# pipe  1183   2
# pipe gen 617
#
# connector  617   1
# connector produce 1182
# connector produce 1212
#
# pipe  1212   2
# pipe gen 628
#
#
# pipe  1188   1
# pipe gen 623
#
# connector  623   1
# connector produce 1189
# connector produce 1193
#
# pipe  1193   2
# pipe gen 622
#
# connector  622   1
# connector produce 1192
# connector produce 1195
#
# pipe  1195   2
# pipe gen 621
#
# connector  621   1
# connector produce 1194
# connector produce 1202
#
# pipe  1202   2
# pipe gen 624
#
# connector  624   1
# connector produce 1200
# connector produce 1262
#
# pipe  1200   2
# pipe gen 625
# pipe  1262   2
# pipe gen 655
#
# connector  625   2
# connector produce 1198
# connector produce 1201
# connector  655   2
# connector produce 1996
# connector produce 1190
#
# pipe  1198   4
# pipe gen 626
# pipe  1996   4
# pipe gen 1114
# pipe  1190   4
# pipe gen 657
#
# connector  626   3
# connector produce 1196
# connector produce 1199
# connector  1114   3
# connector produce 1260
# connector produce 1997
# connector  657   3
# connector produce 1191
# connector produce 1990
#
# pipe  1260   6
# pipe gen 656
# pipe  1990   6
# pipe gen 1111
#
# connector  656   2
# connector produce 1258
# connector produce 1261
# connector  1111   2
# connector produce 1266
# connector produce 1991
#
# pipe  1266   4
# pipe gen 658
#
# connector  658   1
# connector produce 1264
# connector produce 1267
#
#
#
# pipe  1255   1
# pipe gen 652
#
# connector  652   1
# connector produce 1254
# connector produce 1246
#
# pipe  1246   2
# pipe gen 651
#
# connector  651   1
# connector produce 1247
# connector produce 1249
#
# pipe  1249   2
# pipe gen 650
#
# connector  650   1
# connector produce 1248
# connector produce 1251
#
# pipe  1251   2
# pipe gen 649
#
# connector  649   1
# connector produce 1170
# connector produce 1250
#
# pipe  1170   2
# pipe gen 611
#
#
# pipe  1269   1
# pipe gen 659
#
# connector  659   1
# connector produce 157
# connector produce 1268
#
# pipe  157   2
# pipe gen 95
#
# connector  95   1
# connector produce 155
# connector produce 156
#
# pipe  155   2
# pipe gen 94
#
# connector  94   1
# connector produce 151
# connector produce 154
#
# pipe  151   2
# pipe gen 93
#
# connector  93   1
# connector produce 150
# connector produce 153
#
# pipe  153   2
# pipe gen 92
#
# connector  92   1
# connector produce 147
# connector produce 152
#
# pipe  147   2
# pipe gen 91
#
# connector  91   1
# connector produce 146
# connector produce 149
#
# pipe  149   2
# pipe gen 90
#
# connector  90   1
# connector produce 144
# connector produce 148
#
# pipe  144   2
# pipe gen 1159
#
# connector  1159   1
#
# pipe  1290   1
# pipe gen 669
#
# connector  669   1
# connector produce 1289
# connector produce 1291
#
# pipe  1289   2
# pipe gen 668
#
# connector  668   1
# connector produce 461
# connector produce 1288
#
# pipe  461   2
# pipe gen 1136
#
# connector  1136   1
# connector produce 2044
# connector produce 460
#
# pipe  2044   2
# pipe gen 1137
#
# connector  1137   1
# connector produce 2045
# connector produce 2058
#
# pipe  2058   2
# pipe gen 1143
#
# connector  1143   1
# connector produce 2056
# connector produce 2042
#
# pipe  2056   2
# pipe gen 1144
# pipe  2042   2
# pipe gen 1138
#
# connector  1144   2
# connector produce 2035
# connector produce 2057
# connector  1138   2
# connector produce 2041
# connector produce 2043
#
# pipe  2035   4
# pipe gen 1132
# pipe  2041   4
# pipe gen 1135
#
# connector  1132   2
# connector produce 2016
# connector produce 2034
# connector  1135   2
# connector produce 2037
# connector produce 2040
#
# pipe  2016   4
# pipe gen 1126
# pipe  2037   4
# pipe gen 1133
#
# connector  1126   2
# connector produce 2017
# connector produce 2024
# connector  1133   2
# connector produce 2018
# connector produce 2036
#
# pipe  2024   4
# pipe gen 1127
# pipe  2018   4
# pipe gen 1127
#
# connector  1127   2
# connector produce 2019
# connector produce 2026
#
# pipe  2026   2
# pipe gen 1128
#
# connector  1128   1
# connector produce 2021
# connector produce 2022
#
# pipe  2021   2
# pipe gen 1134
# pipe  2022   2
# pipe gen 1129
#
# connector  1134   2
# connector produce 2020
# connector produce 2038
# connector  1129   2
# connector produce 2023
# connector produce 2028
#
# pipe  2038   4
# pipe gen 1139
# pipe  2028   4
# pipe gen 1130
#
# connector  1139   2
# connector produce 2039
# connector produce 2048
# connector  1130   2
# connector produce 2029
# connector produce 2032
#
# pipe  2048   4
# pipe gen 1142
# pipe  2032   4
# pipe gen 1131
#
# connector  1142   2
# connector produce 2049
# connector produce 2051
# connector  1131   2
# connector produce 2030
# connector produce 2033
#
# pipe  2051   4
# pipe gen 1141
#
# connector  1141   1
# connector produce 2050
# connector produce 2053
#
# pipe  2053   2
# pipe gen 1140
#
# connector  1140   1
# connector produce 2052
# connector produce 466
#
# pipe  466   2
# pipe gen 673
#
# connector  673   1
# connector produce 467
# connector produce 1308
#
# pipe  1308   2
# pipe gen 675
#
# connector  675   1
# connector produce 1306
# connector produce 1302
#
# pipe  1302   2
# pipe gen 674
#
# connector  674   1
# connector produce 1303
# connector produce 1304
#
#
# pipe  1292   1
# pipe gen 670
#
# connector  670   1
# connector produce 1293
# connector produce 1300
#
# pipe  1300   2
# pipe gen 672
#
# connector  672   1
# connector produce 1298
# connector produce 1294
#
# pipe  1294   2
# pipe gen 671
#
# connector  671   1
# connector produce 1295
# connector produce 1296
#
#
# pipe  1311   1
# pipe gen 676
#
# connector  676   1
# connector produce 1314
# connector produce 1310
#
# pipe  1314   2
# pipe gen 677
#
# connector  677   1
# connector produce 1313
# connector produce 1315
#
#
# pipe  1316   1
# pipe gen 676
#
#
# pipe  1319   1
# pipe gen 678
#
# connector  678   1
# connector produce 1318
# connector produce 1324
#
# pipe  1324   2
# pipe gen 679
#
# connector  679   1
# connector produce 1325
# connector produce 1328
#
# pipe  1328   2
# pipe gen 680
#
# connector  680   1
# connector produce 1326
# connector produce 1322
#
# pipe  1326   2
# pipe gen 681
# pipe  1322   2
# pipe gen 684
#
# connector  681   2
# connector produce 1320
# connector produce 1327
# connector  684   2
# connector produce 1323
# connector produce 1333
#
# pipe  1333   4
# pipe gen 683
#
# connector  683   1
# connector produce 1332
# connector produce 1335
#
# pipe  1335   2
# pipe gen 682
#
# connector  682   1
# connector produce 1330
# connector produce 1334
#
#
# pipe  1347   1
# pipe gen 690
#
# connector  690   1
# connector produce 1341
# connector produce 1346
#
# pipe  1341   2
# pipe gen 686
#
# connector  686   1
# connector produce 1340
# connector produce 1339
#
# pipe  1339   2
# pipe gen 685
#
# connector  685   1
# connector produce 1338
# connector produce 1337
#
# pipe  1337   2
# pipe gen 689
#
# connector  689   1
# connector produce 1336
# connector produce 1343
#
# pipe  1343   2
# pipe gen 688
#
# connector  688   1
# connector produce 1345
# connector produce 1342
#
# pipe  1345   2
# pipe gen 687
#
# connector  687   1
# connector produce 7
# connector produce 1344
#
# pipe  7   2
# pipe gen 16
#
# connector  16   1
# connector produce 5
# connector produce 6
#
# pipe  5   2
# pipe gen 1052
#
# connector  1052   1
# connector produce 1916
# connector produce 4
#
# pipe  1916   2
# pipe gen 1053
#
# connector  1053   1
# connector produce 1919
# connector produce 1880
#
# pipe  1919   2
# pipe gen 15
# pipe  1880   2
# pipe gen 1019
#
# connector  15   2
# connector produce 1
# connector produce 1918
# connector  1019   2
# connector produce 1878
# connector produce 1881
#
# pipe  1   4
# pipe gen 14
# pipe  1878   4
# pipe gen 1020
#
# connector  14   2
# connector produce 0
# connector produce 3
# connector  1020   2
# connector produce 1879
# connector produce 1886
#
# pipe  3   4
# pipe gen 1245
# pipe  1886   4
# pipe gen 1021
#
# connector  1245   2
# connector produce 2
# connector produce 2227
# connector  1021   2
# connector produce 1884
# connector produce 1887
#
# pipe  2227   4
# pipe gen 1244
# pipe  1884   4
# pipe gen 1022
#
# connector  1244   2
# connector produce 2192
# connector produce 2226
# connector  1022   2
# connector produce 1885
# connector produce 1888
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pipe  1443   1
# pipe gen 756
#
# connector  756   1
# connector produce 1442
# connector produce 1487
#
#
#
#
#
#
#
#
#
#
#
#
#
# pipe  1467   1
# pipe gen 754
#
# connector  754   1
# connector produce 1466
# connector produce 1483
#
#
#
#
#
# pipe  1475   1
# pipe gen 753
#
# connector  753   1
# connector produce 1474
# connector produce 1479
#
#
# pipe  1505   1
# pipe gen 768
#
# connector  768   1
# connector produce 1514
# connector produce 1504
#
# pipe  1514   2
# pipe gen 769
#
# connector  769   1
# connector produce 1513
# connector produce 1515
#
#
#
#
#
# pipe  1540   1
# pipe gen 782
#
# connector  782   1
# connector produce 1537
# connector produce 1541
#
# pipe  1537   2
# pipe gen 781
#
# connector  781   1
# connector produce 1536
# connector produce 1539
#
# pipe  1539   2
# pipe gen 780
#
# connector  780   1
# connector produce 1533
# connector produce 1538
#
# pipe  1533   2
# pipe gen 783
#
# ...
# [[1311, 'pipe'], [1310, 'pipe'], [676, 'connector'], [1314, 'pipe'], [1315, 'pipe'], [677, 'connector'], [1313, 'pipe'], [1312, 'pipe']]
# [[1316, 'pipe'], [1317, 'pipe']]
# [[1319, 'pipe'], [1318, 'pipe'], [678, 'connector'], [1324, 'pipe'], [1325, 'pipe'], [679, 'connector'], [1328, 'pipe'], [1329, 'pipe'], [680, 'connector'], [1326, 'pipe'], [1327, 'pipe'], [1322, 'pipe'], [1323, 'pipe'], [681, 'connector'], [684, 'connector'], [1320, 'pipe'], [1321, 'pipe'], [1333, 'pipe'], [1332, 'pipe'], [683, 'connector'], [1335, 'pipe'], [1334, 'pipe'], [682, 'connector'], [1330, 'pipe'], [1331, 'pipe']]
# [[1347, 'pipe'], [1346, 'pipe'], [690, 'connector'], [1341, 'pipe'], [1340, 'pipe'], [686, 'connector'], [1339, 'pipe'], [1338, 'pipe'], [685, 'connector'], [1337, 'pipe'], [1336, 'pipe'], [689, 'connector'], [1343, 'pipe'], [1342, 'pipe'], [688, 'connector'], [1345, 'pipe'], [1344, 'pipe'], [687, 'connector'], [7, 'pipe'], [6, 'pipe'], [16, 'connector'], [5, 'pipe'], [4, 'pipe'], [1052, 'connector'], [1916, 'pipe'], [1917, 'pipe'], [1053, 'connector'], [1919, 'pipe'], [1918, 'pipe'], [1880, 'pipe'], [1881, 'pipe'], [15, 'connector'], [1019, 'connector'], [1, 'pipe'], [0, 'pipe'], [1878, 'pipe'], [1879, 'pipe'], [14, 'connector'], [1020, 'connector'], [3, 'pipe'], [2, 'pipe'], [1886, 'pipe'], [1887, 'pipe'], [1245, 'connector'], [1021, 'connector'], [2227, 'pipe'], [2226, 'pipe'], [1884, 'pipe'], [1885, 'pipe'], [1244, 'connector'], [1022, 'connector'], [2192, 'pipe'], [2193, 'pipe'], [1888, 'pipe'], [1889, 'pipe']]
